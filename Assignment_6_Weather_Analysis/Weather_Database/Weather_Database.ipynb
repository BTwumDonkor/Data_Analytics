# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 794

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

# Create endpoint URL with each city.
city_url = url + "&q=" + cities[i]

    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_current_weather })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | avarua
# Processing Record 2 of Set 16 | ushuaia
# Processing Record 3 of Set 16 | naryan-mar
# Processing Record 4 of Set 16 | mataura
# Processing Record 5 of Set 16 | kloulklubed
# Processing Record 6 of Set 16 | ketchikan
# Processing Record 7 of Set 16 | deputatskiy
# Processing Record 8 of Set 16 | atuona
# Processing Record 9 of Set 16 | santiago
# Processing Record 10 of Set 16 | kasane
# Processing Record 11 of Set 16 | jamestown
# Processing Record 12 of Set 16 | tidore
# City not found. Skipping...
# Processing Record 13 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 16 | kaitangata
# Processing Record 15 of Set 16 | sefton
# Processing Record 16 of Set 16 | maroantsetra
# Processing Record 17 of Set 16 | hobart
# Processing Record 18 of Set 16 | alofi
# Processing Record 19 of Set 16 | longyearbyen
# Processing Record 20 of Set 16 | mujiayingzi
# Processing Record 21 of Set 16 | labuhan
# Processing Record 22 of Set 16 | airai
# Processing Record 23 of Set 16 | kahului
# Processing Record 24 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 16 | saint george
# Processing Record 26 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 16 | albany
# Processing Record 28 of Set 16 | los llanos de aridane
# Processing Record 29 of Set 16 | cape town
# Processing Record 30 of Set 16 | punta arenas
# Processing Record 31 of Set 16 | rikitea
# Processing Record 32 of Set 16 | shingu
# Processing Record 33 of Set 16 | barrow
# Processing Record 34 of Set 16 | norman wells
# Processing Record 35 of Set 16 | severo-yeniseyskiy
# Processing Record 36 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 16 | port alfred
# Processing Record 38 of Set 16 | xichang
# Processing Record 39 of Set 16 | cidreira
# Processing Record 40 of Set 16 | krasnogorskiy
# Processing Record 41 of Set 16 | nikolskoye
# Processing Record 42 of Set 16 | hermanus
# Processing Record 43 of Set 16 | southbridge
# Processing Record 44 of Set 16 | hilo
# Processing Record 45 of Set 16 | comodoro rivadavia
# Processing Record 46 of Set 16 | kamenka
# Processing Record 47 of Set 16 | ahipara
# Processing Record 48 of Set 16 | merauke
# Processing Record 49 of Set 16 | dandong
# Processing Record 50 of Set 16 | bengkulu
# Processing Record 1 of Set 17 | mucurapo
# Processing Record 2 of Set 17 | mangai
# Processing Record 3 of Set 17 | byron bay
# Processing Record 4 of Set 17 | thompson
# Processing Record 5 of Set 17 | sulina
# Processing Record 6 of Set 17 | matagami
# Processing Record 7 of Set 17 | san juan
# Processing Record 8 of Set 17 | tasiilaq
# Processing Record 9 of Set 17 | yellowknife
# Processing Record 10 of Set 17 | makinsk
# Processing Record 11 of Set 17 | vaini
# Processing Record 12 of Set 17 | severo-kurilsk
# Processing Record 13 of Set 17 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 17 | vardo
# Processing Record 15 of Set 17 | pisco
# Processing Record 16 of Set 17 | zeya
# Processing Record 17 of Set 17 | maragogi
# Processing Record 18 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 17 | preobrazheniye
# Processing Record 20 of Set 17 | panguna
# Processing Record 21 of Set 17 | lasa
# Processing Record 22 of Set 17 | canchungo
# Processing Record 23 of Set 17 | sistranda
# Processing Record 24 of Set 17 | ormara
# Processing Record 25 of Set 17 | christchurch
# Processing Record 26 of Set 17 | port elizabeth
# Processing Record 27 of Set 17 | gora
# Processing Record 28 of Set 17 | talas
# Processing Record 29 of Set 17 | gravdal
# Processing Record 30 of Set 17 | teya
# Processing Record 31 of Set 17 | santa vitoria
# Processing Record 32 of Set 17 | busselton
# Processing Record 33 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 17 | marzuq
# Processing Record 35 of Set 17 | hami
# Processing Record 36 of Set 17 | cedar city
# Processing Record 37 of Set 17 | bredasdorp
# Processing Record 38 of Set 17 | beringovskiy
# Processing Record 39 of Set 17 | nuuk
# Processing Record 40 of Set 17 | port augusta
# Processing Record 41 of Set 17 | bethel
# Processing Record 42 of Set 17 | husavik
# Processing Record 43 of Set 17 | pandan
# Processing Record 44 of Set 17 | bonavista
# Processing Record 45 of Set 17 | ancud
# Processing Record 46 of Set 17 | presidente epitacio
# Processing Record 47 of Set 17 | caravelas
# Processing Record 48 of Set 17 | san policarpo
# Processing Record 49 of Set 17 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 17 | inirida
# Processing Record 1 of Set 18 | saskylakh
# Processing Record 2 of Set 18 | perth
# Processing Record 3 of Set 18 | puerto ayora
# Processing Record 4 of Set 18 | grindavik
# Processing Record 5 of Set 18 | noumea
# Processing Record 6 of Set 18 | grand gaube
# Processing Record 7 of Set 18 | bandarbeyla
# Processing Record 8 of Set 18 | lakatoro
# Processing Record 9 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 18 | east london
# Processing Record 11 of Set 18 | upernavik
# Processing Record 12 of Set 18 | roebourne
# Processing Record 13 of Set 18 | canico
# Processing Record 14 of Set 18 | laguna
# Processing Record 15 of Set 18 | esperance
# Processing Record 16 of Set 18 | kukshi
# Processing Record 17 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 18 | vila velha
# Processing Record 19 of Set 18 | butaritari
# Processing Record 20 of Set 18 | manokwari
# Processing Record 21 of Set 18 | novovasylivka
# Processing Record 22 of Set 18 | demirci
# Processing Record 23 of Set 18 | bogo
# Processing Record 24 of Set 18 | wakkanai
# Processing Record 25 of Set 18 | umm kaddadah
# Processing Record 26 of Set 18 | bluff
# Processing Record 27 of Set 18 | celestun
# Processing Record 28 of Set 18 | geraldton
# Processing Record 29 of Set 18 | mercedes
# Processing Record 30 of Set 18 | alberton
# Processing Record 31 of Set 18 | kayes
# Processing Record 32 of Set 18 | ribeira grande
# Processing Record 33 of Set 18 | pecos
# Processing Record 34 of Set 18 | yulara
# Processing Record 35 of Set 18 | kathu
# Processing Record 36 of Set 18 | qaanaaq
# Processing Record 37 of Set 18 | sison
# Processing Record 38 of Set 18 | flinders
# Processing Record 39 of Set 18 | manaure
# Processing Record 40 of Set 18 | yeppoon
# Processing Record 41 of Set 18 | pontianak
# Processing Record 42 of Set 18 | saint-philippe
# Processing Record 43 of Set 18 | gubakha
# Processing Record 44 of Set 18 | shache
# Processing Record 45 of Set 18 | hithadhoo
# Processing Record 46 of Set 18 | la ronge
# Processing Record 47 of Set 18 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 18 | hovd
# Processing Record 49 of Set 18 | valparaiso
# Processing Record 50 of Set 18 | conceicao da barra
# Processing Record 1 of Set 19 | new norfolk
# Processing Record 2 of Set 19 | casablanca
# Processing Record 3 of Set 19 | lebu
# Processing Record 4 of Set 19 | rock sound
# Processing Record 5 of Set 19 | marondera
# Processing Record 6 of Set 19 | la romana
# Processing Record 7 of Set 19 | sabang
# Processing Record 8 of Set 19 | ambulu
# Processing Record 9 of Set 19 | pedernales
# Processing Record 10 of Set 19 | bongandanga
# Processing Record 11 of Set 19 | billings
# Processing Record 12 of Set 19 | vire
# Processing Record 13 of Set 19 | maniitsoq
# Processing Record 14 of Set 19 | haines junction
# Processing Record 15 of Set 19 | athabasca
# Processing Record 16 of Set 19 | saint-pierre
# Processing Record 17 of Set 19 | liverpool
# Processing Record 18 of Set 19 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 19 | cabo san lucas
# Processing Record 20 of Set 19 | kavieng
# Processing Record 21 of Set 19 | yerbogachen
# Processing Record 22 of Set 19 | lata
# Processing Record 23 of Set 19 | arraial do cabo
# Processing Record 24 of Set 19 | guymon
# Processing Record 25 of Set 19 | shubarshi
# Processing Record 26 of Set 19 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 19 | santona
# Processing Record 28 of Set 19 | papetoai
# Processing Record 29 of Set 19 | kodiak
# Processing Record 30 of Set 19 | krasnoarmeysk
# Processing Record 31 of Set 19 | jalu
# Processing Record 32 of Set 19 | kapaa
# Processing Record 33 of Set 19 | georgetown
# Processing Record 34 of Set 19 | dabat
# Processing Record 35 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 19 | san jose
# Processing Record 37 of Set 19 | kutum
# Processing Record 38 of Set 19 | khandbari
# Processing Record 39 of Set 19 | sonepur
# Processing Record 40 of Set 19 | tessalit
# Processing Record 41 of Set 19 | fereydun kenar
# Processing Record 42 of Set 19 | lubana
# Processing Record 43 of Set 19 | dongsheng
# Processing Record 44 of Set 19 | sur
# Processing Record 45 of Set 19 | alta floresta
# Processing Record 46 of Set 19 | castro
# Processing Record 47 of Set 19 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 19 | nanortalik
# Processing Record 49 of Set 19 | bambous virieux
# Processing Record 50 of Set 19 | ponta do sol
# Processing Record 1 of Set 20 | adrar
# Processing Record 2 of Set 20 | viedma
# Processing Record 3 of Set 20 | egvekinot
# Processing Record 4 of Set 20 | margate
# Processing Record 5 of Set 20 | talnakh
# Processing Record 6 of Set 20 | khatanga
# Processing Record 7 of Set 20 | maneromango
# Processing Record 8 of Set 20 | imbituba
# Processing Record 9 of Set 20 | bathsheba
# Processing Record 10 of Set 20 | ossora
# Processing Record 11 of Set 20 | wahran
# City not found. Skipping...
# Processing Record 12 of Set 20 | isiro
# Processing Record 13 of Set 20 | mehamn
# Processing Record 14 of Set 20 | inhambane
# Processing Record 15 of Set 20 | namibe
# Processing Record 16 of Set 20 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 20 | burica
# City not found. Skipping...
# Processing Record 18 of Set 20 | nome
# Processing Record 19 of Set 20 | pucallpa
# Processing Record 20 of Set 20 | faanui
# Processing Record 21 of Set 20 | chipinge
# Processing Record 22 of Set 20 | chuy
# Processing Record 23 of Set 20 | rio grande
# Processing Record 24 of Set 20 | camacha
# Processing Record 25 of Set 20 | saldanha
# Processing Record 26 of Set 20 | sivaki
# Processing Record 27 of Set 20 | langxiang
# Processing Record 28 of Set 20 | lorengau
# Processing Record 29 of Set 20 | port macquarie
# Processing Record 30 of Set 20 | tuktoyaktuk
# Processing Record 31 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 20 | godinesti
# Processing Record 33 of Set 20 | roma
# Processing Record 34 of Set 20 | jefferson city
# Processing Record 35 of Set 20 | victoria
# Processing Record 36 of Set 20 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 20 | uroteppa
# City not found. Skipping...
# Processing Record 38 of Set 20 | sitka
# Processing Record 39 of Set 20 | antsohihy
# Processing Record 40 of Set 20 | klaksvik
# Processing Record 41 of Set 20 | usmajac
# Processing Record 42 of Set 20 | naze
# Processing Record 43 of Set 20 | saint-francois
# Processing Record 44 of Set 20 | sao filipe
# Processing Record 45 of Set 20 | torbay
# Processing Record 46 of Set 20 | dubrovka
# Processing Record 47 of Set 20 | zarubino
# Processing Record 48 of Set 20 | itarema
# Processing Record 49 of Set 20 | collie
# Processing Record 50 of Set 20 | siverek
# Processing Record 1 of Set 21 | hailar
# Processing Record 2 of Set 21 | kruisfontein
# Processing Record 3 of Set 21 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 21 | nouadhibou
# Processing Record 5 of Set 21 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 21 | codrington
# Processing Record 7 of Set 21 | ornskoldsvik
# Processing Record 8 of Set 21 | tautira
# Processing Record 9 of Set 21 | tubruq
# City not found. Skipping...
# Processing Record 10 of Set 21 | sosnovo-ozerskoye
# Processing Record 11 of Set 21 | qui nhon
# Processing Record 12 of Set 21 | dosso
# Processing Record 13 of Set 21 | cabedelo
# Processing Record 14 of Set 21 | richards bay
# Processing Record 15 of Set 21 | puerto escondido
# Processing Record 16 of Set 21 | hamilton
# Processing Record 17 of Set 21 | surgut
# Processing Record 18 of Set 21 | santa rosa
# Processing Record 19 of Set 21 | hasaki
# Processing Record 20 of Set 21 | vostok
# Processing Record 21 of Set 21 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 21 | luderitz
# Processing Record 23 of Set 21 | dikson
# Processing Record 24 of Set 21 | escanaba
# Processing Record 25 of Set 21 | amapa
# Processing Record 26 of Set 21 | necochea
# Processing Record 27 of Set 21 | kantunilkin
# Processing Record 28 of Set 21 | ust-omchug
# Processing Record 29 of Set 21 | quelimane
# Processing Record 30 of Set 21 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 21 | baisha
# Processing Record 32 of Set 21 | opuwo
# Processing Record 33 of Set 21 | san angelo
# Processing Record 34 of Set 21 | dera ghazi khan
# Processing Record 35 of Set 21 | mar del plata
# Processing Record 36 of Set 21 | ruteng
# Processing Record 37 of Set 21 | grants
# Processing Record 38 of Set 21 | salalah
# Processing Record 39 of Set 21 | waipawa
# Processing Record 40 of Set 21 | batemans bay
# Processing Record 41 of Set 21 | mersing
# Processing Record 42 of Set 21 | gat
# Processing Record 43 of Set 21 | pietersburg
# Processing Record 44 of Set 21 | lethem
# Processing Record 45 of Set 21 | mantua
# Processing Record 46 of Set 21 | bafra
# Processing Record 47 of Set 21 | sechura
# Processing Record 48 of Set 21 | chokurdakh
# Processing Record 49 of Set 21 | boddam
# Processing Record 50 of Set 21 | phibun mangsahan
# Processing Record 1 of Set 22 | leshukonskoye
# Processing Record 2 of Set 22 | thanh hoa
# Processing Record 3 of Set 22 | mareeba
# Processing Record 4 of Set 22 | honiara
# Processing Record 5 of Set 22 | abaujszanto
# Processing Record 6 of Set 22 | chimbote
# Processing Record 7 of Set 22 | hofn
# Processing Record 8 of Set 22 | sao joao da barra
# Processing Record 9 of Set 22 | mudbidri
# Processing Record 10 of Set 22 | vuktyl
# Processing Record 11 of Set 22 | provideniya
# Processing Record 12 of Set 22 | kirakira
# Processing Record 13 of Set 22 | vila franca do campo
# Processing Record 14 of Set 22 | quatre cocos
# Processing Record 15 of Set 22 | carnarvon
# Processing Record 16 of Set 22 | mukhen
# Processing Record 17 of Set 22 | clyde river
# Processing Record 18 of Set 22 | marsh harbour
# Processing Record 19 of Set 22 | moree
# Processing Record 20 of Set 22 | souillac
# Processing Record 21 of Set 22 | kalmunai
# Processing Record 22 of Set 22 | severobaykalsk
# Processing Record 23 of Set 22 | debre tabor
# Processing Record 24 of Set 22 | potsdam
# Processing Record 25 of Set 22 | pemangkat
# Processing Record 26 of Set 22 | bethanien
# Processing Record 27 of Set 22 | alegrete
# Processing Record 28 of Set 22 | tayoltita
# Processing Record 29 of Set 22 | pringsewu
# Processing Record 30 of Set 22 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 22 | takanabe
# Processing Record 32 of Set 22 | ekhabi
# Processing Record 33 of Set 22 | zaysan
# Processing Record 34 of Set 22 | kang
# Processing Record 35 of Set 22 | taltal
# Processing Record 36 of Set 22 | saravan
# Processing Record 37 of Set 22 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 22 | uvat
# Processing Record 39 of Set 22 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 22 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 22 | kyaikkami
# Processing Record 42 of Set 22 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 22 | wangaratta
# Processing Record 44 of Set 22 | mama
# Processing Record 45 of Set 22 | shubarkuduk
# Processing Record 46 of Set 22 | bodden town
# Processing Record 47 of Set 22 | bima
# Processing Record 48 of Set 22 | port blair
# Processing Record 49 of Set 22 | chapadinha
# Processing Record 50 of Set 22 | hokitika
# Processing Record 1 of Set 23 | tura
# Processing Record 2 of Set 23 | ongwediva
# Processing Record 3 of Set 23 | atar
# Processing Record 4 of Set 23 | aksu
# Processing Record 5 of Set 23 | corinto
# Processing Record 6 of Set 23 | thatta
# Processing Record 7 of Set 23 | lahaina
# Processing Record 8 of Set 23 | mufumbwe
# Processing Record 9 of Set 23 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 23 | lucea
# Processing Record 11 of Set 23 | chase
# Processing Record 12 of Set 23 | cabinda
# Processing Record 13 of Set 23 | san pedro pinula
# Processing Record 14 of Set 23 | itoman
# Processing Record 15 of Set 23 | orlik
# Processing Record 16 of Set 23 | cabras
# Processing Record 17 of Set 23 | acajutla
# Processing Record 18 of Set 23 | eregli
# Processing Record 19 of Set 23 | hobyo
# Processing Record 20 of Set 23 | maracanau
# Processing Record 21 of Set 23 | rivne
# Processing Record 22 of Set 23 | verkhnyaya salda
# Processing Record 23 of Set 23 | saint-ambroise
# Processing Record 24 of Set 23 | kampot
# Processing Record 25 of Set 23 | grenfell
# Processing Record 26 of Set 23 | saint-georges
# Processing Record 27 of Set 23 | vaitape
# Processing Record 28 of Set 23 | clarence town
# Processing Record 29 of Set 23 | bandipur
# Processing Record 30 of Set 23 | korla
# Processing Record 31 of Set 23 | kargasok
# Processing Record 32 of Set 23 | te anau
# Processing Record 33 of Set 23 | la palma
# Processing Record 34 of Set 23 | yelizovo
# Processing Record 35 of Set 23 | sergeyevka
# Processing Record 36 of Set 23 | constitucion
# Processing Record 37 of Set 23 | pangnirtung
# Processing Record 38 of Set 23 | itaituba
# Processing Record 39 of Set 23 | archena
# Processing Record 40 of Set 23 | emba
# Processing Record 41 of Set 23 | bay city
# Processing Record 42 of Set 23 | kollegal
# Processing Record 43 of Set 23 | asau
# Processing Record 44 of Set 23 | evensk
# Processing Record 45 of Set 23 | tupelo
# Processing Record 46 of Set 23 | sept-iles
# Processing Record 47 of Set 23 | port hedland
# Processing Record 48 of Set 23 | hervey bay
# Processing Record 49 of Set 23 | katsuura
# Processing Record 50 of Set 23 | am timan
# Processing Record 1 of Set 24 | shakawe
# Processing Record 2 of Set 24 | half moon bay
# Processing Record 3 of Set 24 | lebanon
# Processing Record 4 of Set 24 | huaihua
# Processing Record 5 of Set 24 | pevek
# Processing Record 6 of Set 24 | umm lajj
# Processing Record 7 of Set 24 | berlevag
# Processing Record 8 of Set 24 | aleksandrov gay
# Processing Record 9 of Set 24 | guerrero negro
# Processing Record 10 of Set 24 | gigmoto
# Processing Record 11 of Set 24 | mananara
# Processing Record 12 of Set 24 | bagdarin
# Processing Record 13 of Set 24 | dir
# Processing Record 14 of Set 24 | port lincoln
# Processing Record 15 of Set 24 | umirim
# Processing Record 16 of Set 24 | alexandria
# Processing Record 17 of Set 24 | baiyin
# Processing Record 18 of Set 24 | songea
# Processing Record 19 of Set 24 | salinas
# Processing Record 20 of Set 24 | oltu
# Processing Record 21 of Set 24 | lazaro cardenas
# Processing Record 22 of Set 24 | verkhoyansk
# Processing Record 23 of Set 24 | takikawa
# Processing Record 24 of Set 24 | borogontsy
# Processing Record 25 of Set 24 | nichinan
# Processing Record 26 of Set 24 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 24 | cibitoke
# Processing Record 28 of Set 24 | fairbanks
# Processing Record 29 of Set 24 | mahebourg
# Processing Record 30 of Set 24 | aklavik
# Processing Record 31 of Set 24 | muzquiz
# City not found. Skipping...
# Processing Record 32 of Set 24 | gamba
# Processing Record 33 of Set 24 | dicabisagan
# Processing Record 34 of Set 24 | san patricio
# Processing Record 35 of Set 24 | riyadh
# Processing Record 36 of Set 24 | ageo
# Processing Record 37 of Set 24 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 24 | turukhansk
# Processing Record 39 of Set 24 | karacabey
# Processing Record 40 of Set 24 | lahij
# Processing Record 41 of Set 24 | aloha
# Processing Record 42 of Set 24 | cururupu
# Processing Record 43 of Set 24 | talaya
# Processing Record 44 of Set 24 | cherskiy
# Processing Record 45 of Set 24 | bereda
# Processing Record 46 of Set 24 | shaunavon
# Processing Record 47 of Set 24 | kuching
# Processing Record 48 of Set 24 | hambantota
# Processing Record 49 of Set 24 | san quintin
# Processing Record 50 of Set 24 | kieta
# Processing Record 1 of Set 25 | dutse
# Processing Record 2 of Set 25 | henties bay
# Processing Record 3 of Set 25 | sioux lookout
# Processing Record 4 of Set 25 | kant
# Processing Record 5 of Set 25 | chester
# Processing Record 6 of Set 25 | oistins
# Processing Record 7 of Set 25 | opobo
# City not found. Skipping...
# Processing Record 8 of Set 25 | poronaysk
# Processing Record 9 of Set 25 | kashi
# Processing Record 10 of Set 25 | broome
# Processing Record 11 of Set 25 | zonguldak
# Processing Record 12 of Set 25 | montepuez
# Processing Record 13 of Set 25 | zhaotong
# Processing Record 14 of Set 25 | leningradskiy
# Processing Record 15 of Set 25 | manadhoo
# Processing Record 16 of Set 25 | praia da vitoria
# Processing Record 17 of Set 25 | joacaba
# Processing Record 18 of Set 25 | breves
# Processing Record 19 of Set 25 | ilulissat
# Processing Record 20 of Set 25 | siyabuswa
# Processing Record 21 of Set 25 | pascagoula
# Processing Record 22 of Set 25 | storforshei
# Processing Record 23 of Set 25 | mansa
# Processing Record 24 of Set 25 | el tarra
# Processing Record 25 of Set 25 | mackay
# Processing Record 26 of Set 25 | kasongo-lunda
# Processing Record 27 of Set 25 | itaueira
# Processing Record 28 of Set 25 | chernogorsk
# Processing Record 29 of Set 25 | winslow
# Processing Record 30 of Set 25 | zhangjiakou
# Processing Record 31 of Set 25 | westport
# Processing Record 32 of Set 25 | krasnoyarskiy
# Processing Record 33 of Set 25 | dekernes
# Processing Record 34 of Set 25 | yialos
# City not found. Skipping...
# Processing Record 35 of Set 25 | bantou
# Processing Record 36 of Set 25 | tarut
# Processing Record 37 of Set 25 | olafsvik
# Processing Record 38 of Set 25 | seoul
# Processing Record 39 of Set 25 | tigzirt
# Processing Record 40 of Set 25 | srednekolymsk
# Processing Record 41 of Set 25 | silyanah
# City not found. Skipping...
# Processing Record 42 of Set 25 | centralia
# Processing Record 43 of Set 25 | buchanan
# Processing Record 44 of Set 25 | narsaq
# Processing Record 45 of Set 25 | oranjestad
# Processing Record 46 of Set 25 | menongue
# Processing Record 47 of Set 25 | cockburn town
# Processing Record 48 of Set 25 | sinnamary
# Processing Record 49 of Set 25 | ostersund
# Processing Record 50 of Set 25 | nagato
# Processing Record 1 of Set 26 | fort nelson
# Processing Record 2 of Set 26 | jawhar
# Processing Record 3 of Set 26 | kentau
# Processing Record 4 of Set 26 | kimamba
# Processing Record 5 of Set 26 | tazovskiy
# Processing Record 6 of Set 26 | arlit
# Processing Record 7 of Set 26 | visby
# Processing Record 8 of Set 26 | aksarka
# Processing Record 9 of Set 26 | ola
# Processing Record 10 of Set 26 | doha
# Processing Record 11 of Set 26 | dudinka
# Processing Record 12 of Set 26 | durant
# Processing Record 13 of Set 26 | kualakapuas
# Processing Record 14 of Set 26 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 26 | bilma
# Processing Record 16 of Set 26 | saint-joseph
# Processing Record 17 of Set 26 | teseney
# Processing Record 18 of Set 26 | fukue
# Processing Record 19 of Set 26 | iqaluit
# Processing Record 20 of Set 26 | sulangan
# Processing Record 21 of Set 26 | umm ruwabah
# City not found. Skipping...
# Processing Record 22 of Set 26 | te karaka
# Processing Record 23 of Set 26 | bilibino
# Processing Record 24 of Set 26 | luanda
# Processing Record 25 of Set 26 | tiksi
# Processing Record 26 of Set 26 | paamiut
# Processing Record 27 of Set 26 | santa marta
# Processing Record 28 of Set 26 | tianpeng
# Processing Record 29 of Set 26 | hoa binh
# Processing Record 30 of Set 26 | ewa beach
# Processing Record 31 of Set 26 | vestmannaeyjar
# Processing Record 32 of Set 26 | bosaso
# Processing Record 33 of Set 26 | rakaia
# Processing Record 34 of Set 26 | halmstad
# Processing Record 35 of Set 26 | galiwinku
# City not found. Skipping...
# Processing Record 36 of Set 26 | plettenberg bay
# Processing Record 37 of Set 26 | coihaique
# Processing Record 38 of Set 26 | charters towers
# Processing Record 39 of Set 26 | dukat
# Processing Record 40 of Set 26 | temirgoyevskaya
# Processing Record 41 of Set 26 | baoying
# Processing Record 42 of Set 26 | kawalu
# Processing Record 43 of Set 26 | dubbo
# Processing Record 44 of Set 26 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 45 of Set 26 | olinda
# Processing Record 46 of Set 26 | bayan
# Processing Record 47 of Set 26 | surgana
# Processing Record 48 of Set 26 | angoche
# Processing Record 49 of Set 26 | meulaboh
# Processing Record 50 of Set 26 | kisangani
# Processing Record 1 of Set 27 | shillong
# Processing Record 2 of Set 27 | namie
# Processing Record 3 of Set 27 | sakakah
# Processing Record 4 of Set 27 | karamay
# City not found. Skipping...
# Processing Record 5 of Set 27 | lavrentiya
# Processing Record 6 of Set 27 | faya
# Processing Record 7 of Set 27 | mtwara
# Processing Record 8 of Set 27 | alyangula
# Processing Record 9 of Set 27 | road town
# Processing Record 10 of Set 27 | isangel
# Processing Record 11 of Set 27 | sola
# Processing Record 12 of Set 27 | khani
# Processing Record 13 of Set 27 | douglas
# Processing Record 14 of Set 27 | mount gambier
# Processing Record 15 of Set 27 | panguipulli
# Processing Record 16 of Set 27 | tumkur
# Processing Record 17 of Set 27 | skelleftea
# Processing Record 18 of Set 27 | ahuimanu
# Processing Record 19 of Set 27 | labytnangi
# Processing Record 20 of Set 27 | vilhena
# Processing Record 21 of Set 27 | cayenne
# Processing Record 22 of Set 27 | norilsk
# Processing Record 23 of Set 27 | san andres
# Processing Record 24 of Set 27 | panama city
# Processing Record 25 of Set 27 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 27 | lufkin
# Processing Record 27 of Set 27 | moron
# Processing Record 28 of Set 27 | svetlogorsk
# Processing Record 29 of Set 27 | robertsport
# Processing Record 30 of Set 27 | lydenburg
# Processing Record 31 of Set 27 | jucurutu
# Processing Record 32 of Set 27 | gizo
# Processing Record 33 of Set 27 | rawson
# Processing Record 34 of Set 27 | yenagoa
# Processing Record 35 of Set 27 | togur
# Processing Record 36 of Set 27 | iquitos
# Processing Record 37 of Set 27 | murgab
# Processing Record 38 of Set 27 | olga
# Processing Record 39 of Set 27 | mangrol
# Processing Record 40 of Set 27 | lamar
# Processing Record 41 of Set 27 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 27 | marystown
# Processing Record 43 of Set 27 | urusha
# Processing Record 44 of Set 27 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 27 | coquimbo
# Processing Record 46 of Set 27 | san cristobal
# Processing Record 47 of Set 27 | ocumare del tuy
# Processing Record 48 of Set 27 | omboue
# Processing Record 49 of Set 27 | rzhaksa
# Processing Record 50 of Set 27 | gustavo diaz ordaz
# Processing Record 1 of Set 28 | lompoc
# Processing Record 2 of Set 28 | port-cartier
# Processing Record 3 of Set 28 | samarai
# Processing Record 4 of Set 28 | belle fourche
# Processing Record 5 of Set 28 | berea
# Processing Record 6 of Set 28 | gaoual
# Processing Record 7 of Set 28 | zdvinsk
# Processing Record 8 of Set 28 | veraval
# Processing Record 9 of Set 28 | camacupa
# Processing Record 10 of Set 28 | santarem
# Processing Record 11 of Set 28 | juneau
# Processing Record 12 of Set 28 | tarabha
# Processing Record 13 of Set 28 | tuatapere
# Processing Record 14 of Set 28 | berezovyy
# Processing Record 15 of Set 28 | mattru
# Processing Record 16 of Set 28 | tigil
# Processing Record 17 of Set 28 | wamba
# Processing Record 18 of Set 28 | san buenaventura
# Processing Record 19 of Set 28 | otorohanga
# Processing Record 20 of Set 28 | havre
# Processing Record 21 of Set 28 | xiaolingwei
# Processing Record 22 of Set 28 | ada
# Processing Record 23 of Set 28 | balkhash
# Processing Record 24 of Set 28 | tirat karmel
# Processing Record 25 of Set 28 | pitimbu
# Processing Record 26 of Set 28 | oudtshoorn
# Processing Record 27 of Set 28 | warrnambool
# Processing Record 28 of Set 28 | bougouni
# Processing Record 29 of Set 28 | asfi
# Processing Record 30 of Set 28 | cap malheureux
# Processing Record 31 of Set 28 | derzhavinsk
# Processing Record 32 of Set 28 | sao jose do belmonte
# Processing Record 33 of Set 28 | nizhnevartovsk
# Processing Record 34 of Set 28 | belyy yar
# Processing Record 35 of Set 28 | chicama
# Processing Record 36 of Set 28 | boleslawiec
# Processing Record 37 of Set 28 | porto novo
# Processing Record 38 of Set 28 | mecca
# Processing Record 39 of Set 28 | maracaibo
# Processing Record 40 of Set 28 | salinopolis
# Processing Record 41 of Set 28 | sabzevar
# Processing Record 42 of Set 28 | evanston
# Processing Record 43 of Set 28 | kerema
# Processing Record 44 of Set 28 | porto velho
# Processing Record 45 of Set 28 | arkhangelos
# City not found. Skipping...
# Processing Record 46 of Set 28 | kaeo
# Processing Record 47 of Set 28 | kichera
# Processing Record 48 of Set 28 | jinchang
# Processing Record 49 of Set 28 | kasese
# Processing Record 50 of Set 28 | zhob
# Processing Record 1 of Set 29 | desna
# Processing Record 2 of Set 29 | hirado
# Processing Record 3 of Set 29 | neiafu
# Processing Record 4 of Set 29 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 29 | ilo
# Processing Record 6 of Set 29 | pelym
# Processing Record 7 of Set 29 | susanville
# Processing Record 8 of Set 29 | carutapera
# Processing Record 9 of Set 29 | calvinia
# Processing Record 10 of Set 29 | yanan
# City not found. Skipping...
# Processing Record 11 of Set 29 | sorland
# Processing Record 12 of Set 29 | tungor
# Processing Record 13 of Set 29 | rio gallegos
# Processing Record 14 of Set 29 | agirish
# Processing Record 15 of Set 29 | qaqortoq
# Processing Record 16 of Set 29 | gaya
# Processing Record 17 of Set 29 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 29 | velka bites
# Processing Record 19 of Set 29 | ambodifototra
# City not found. Skipping...
# Processing Record 20 of Set 29 | amga
# Processing Record 21 of Set 29 | black river
# Processing Record 22 of Set 29 | kollumerland
# City not found. Skipping...
# Processing Record 23 of Set 29 | port-de-bouc
# Processing Record 24 of Set 29 | vila
# Processing Record 25 of Set 29 | havoysund
# Processing Record 26 of Set 29 | lithgow
# Processing Record 27 of Set 29 | ixtapa
# Processing Record 28 of Set 29 | mayo
# Processing Record 29 of Set 29 | kushmurun
# Processing Record 30 of Set 29 | henderson
# Processing Record 31 of Set 29 | shimoda
# Processing Record 32 of Set 29 | lyubim
# Processing Record 33 of Set 29 | seminole
# Processing Record 34 of Set 29 | kosh-agach
# Processing Record 35 of Set 29 | karratha
# Processing Record 36 of Set 29 | lagos
# Processing Record 37 of Set 29 | svetlyy
# Processing Record 38 of Set 29 | maitum
# Processing Record 39 of Set 29 | zhitikara
# City not found. Skipping...
# Processing Record 40 of Set 29 | loa janan
# Processing Record 41 of Set 29 | nsanje
# Processing Record 42 of Set 29 | yar-sale
# Processing Record 43 of Set 29 | denpasar
# Processing Record 44 of Set 29 | pacific grove
# Processing Record 45 of Set 29 | padang
# Processing Record 46 of Set 29 | anloga
# Processing Record 47 of Set 29 | lom sak
# Processing Record 48 of Set 29 | zilair
# Processing Record 49 of Set 29 | jinxiang
# Processing Record 50 of Set 29 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 30 | sarahan
# Processing Record 2 of Set 30 | mayor pablo lagerenza
# Processing Record 3 of Set 30 | hualmay
# Processing Record 4 of Set 30 | fort saint james
# Processing Record 5 of Set 30 | esso
# Processing Record 6 of Set 30 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 30 | shieli
# Processing Record 8 of Set 30 | quesnel
# Processing Record 9 of Set 30 | zhigansk
# Processing Record 10 of Set 30 | chokwe
# Processing Record 11 of Set 30 | rocha
# Processing Record 12 of Set 30 | bajo baudo
# City not found. Skipping...
# Processing Record 13 of Set 30 | wajid
# Processing Record 14 of Set 30 | pryluky
# Processing Record 15 of Set 30 | wanning
# Processing Record 16 of Set 30 | susurluk
# Processing Record 17 of Set 30 | tilichiki
# Processing Record 18 of Set 30 | ponferrada
# Processing Record 19 of Set 30 | sorong
# Processing Record 20 of Set 30 | hay river
# Processing Record 21 of Set 30 | lima duarte
# Processing Record 22 of Set 30 | dumbea
# Processing Record 23 of Set 30 | wajima
# Processing Record 24 of Set 30 | cam ranh
# Processing Record 25 of Set 30 | ballangen
# Processing Record 26 of Set 30 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 30 | charleville-mezieres
# Processing Record 28 of Set 30 | najran
# Processing Record 29 of Set 30 | touros
# Processing Record 30 of Set 30 | lagoa
# Processing Record 31 of Set 30 | stornoway
# Processing Record 32 of Set 30 | tupancireta
# Processing Record 33 of Set 30 | san carlos
# Processing Record 34 of Set 30 | coahuayana
# Processing Record 35 of Set 30 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 30 | nelson bay
# Processing Record 37 of Set 30 | zaoyang
# Processing Record 38 of Set 30 | eyrarbakki
# Processing Record 39 of Set 30 | raudeberg
# Processing Record 40 of Set 30 | pop
# Processing Record 41 of Set 30 | muyezerskiy
# Processing Record 42 of Set 30 | mulchen
# Processing Record 43 of Set 30 | paucartambo
# City not found. Skipping...
# Processing Record 44 of Set 30 | green river
# Processing Record 45 of Set 30 | marienburg
# Processing Record 46 of Set 30 | porbandar
# Processing Record 47 of Set 30 | takestan
# Processing Record 48 of Set 30 | svay rieng
# Processing Record 49 of Set 30 | merrill
# Processing Record 50 of Set 30 | bubaque
# Processing Record 1 of Set 31 | anadyr
# Processing Record 2 of Set 31 | chifeng
# Processing Record 3 of Set 31 | rawlins
# Processing Record 4 of Set 31 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 31 | jiangyou
# Processing Record 6 of Set 31 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 31 | puhja
# Processing Record 8 of Set 31 | fortuna
# Processing Record 9 of Set 31 | ialibu
# Processing Record 10 of Set 31 | waingapu
# Processing Record 11 of Set 31 | havre-saint-pierre
# Processing Record 12 of Set 31 | high prairie
# Processing Record 13 of Set 31 | cabot
# Processing Record 14 of Set 31 | yamoussoukro
# Processing Record 15 of Set 31 | indianola
# Processing Record 16 of Set 31 | dwarka
# Processing Record 17 of Set 31 | yarada
# Processing Record 18 of Set 31 | lola
# Processing Record 19 of Set 31 | shellbrook
# Processing Record 20 of Set 31 | esmeraldas
# Processing Record 21 of Set 31 | ustupo
# Processing Record 22 of Set 31 | naters
# Processing Record 23 of Set 31 | masiga
# Processing Record 24 of Set 31 | sawtell
# Processing Record 25 of Set 31 | fevralsk
# City not found. Skipping...
# Processing Record 26 of Set 31 | laja
# Processing Record 27 of Set 31 | banjar
# Processing Record 28 of Set 31 | slave lake
# Processing Record 29 of Set 31 | oranzherei
# Processing Record 30 of Set 31 | mahibadhoo
# Processing Record 31 of Set 31 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 31 | subang
# Processing Record 33 of Set 31 | bokspits
# City not found. Skipping...
# Processing Record 34 of Set 31 | santiago del estero
# Processing Record 35 of Set 31 | sabha
# Processing Record 36 of Set 31 | toora-khem
# Processing Record 37 of Set 31 | las rozas de madrid
# Processing Record 38 of Set 31 | tyukalinsk
# Processing Record 39 of Set 31 | dipkarpaz
# City not found. Skipping...
# Processing Record 40 of Set 31 | tawkar
# City not found. Skipping...
# Processing Record 41 of Set 31 | chazuta
# Processing Record 42 of Set 31 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 31 | macaboboni
# City not found. Skipping...
# Processing Record 44 of Set 31 | ramos arizpe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
original_city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Avarua      CK -21.2078 -159.7750     84.25        74          15
# 1      Ushuaia      AR -54.8000  -68.3000     42.31        98          90
# 2   Naryan-Mar      RU  67.6713   53.0870      5.54        97          81
# 3      Mataura      NZ -46.1927  168.8643     56.48        54          57
# 4  Kloulklubed      PW   7.0419  134.2556     82.90        76          66
# 5    Ketchikan      US  55.3422 -131.6461     50.47        25           0
# 6  Deputatskiy      RU  69.3000  139.9000      9.09        73         100
# 7       Atuona      PF  -9.8000 -139.0333     78.94        78          20
# 8     Santiago      CL -33.4569  -70.6483     63.18        62           0
# 9       Kasane      BW -17.8167   25.1500     70.09        71          66
#
#    Wind Speed Current Description
# 0        8.05          few clouds
# 1        6.29       moderate rain
# 2        6.13       broken clouds
# 3       13.40       broken clouds
# 4        6.44       broken clouds
# 5       10.36           clear sky
# 6        2.39     overcast clouds
# 7       16.02          light rain
# 8        8.05           clear sky
# 9        3.24       broken clouds

# %%
# Rearrange columns.
city_data_df = original_city_data_df[["City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Avarua      CK -21.2078 -159.7750     84.25        74          15
# 1      Ushuaia      AR -54.8000  -68.3000     42.31        98          90
# 2   Naryan-Mar      RU  67.6713   53.0870      5.54        97          81
# 3      Mataura      NZ -46.1927  168.8643     56.48        54          57
# 4  Kloulklubed      PW   7.0419  134.2556     82.90        76          66
# 5    Ketchikan      US  55.3422 -131.6461     50.47        25           0
# 6  Deputatskiy      RU  69.3000  139.9000      9.09        73         100
# 7       Atuona      PF  -9.8000 -139.0333     78.94        78          20
# 8     Santiago      CL -33.4569  -70.6483     63.18        62           0
# 9       Kasane      BW -17.8167   25.1500     70.09        71          66
#
#    Wind Speed Current Description
# 0        8.05          few clouds
# 1        6.29       moderate rain
# 2        6.13       broken clouds
# 3       13.40       broken clouds
# 4        6.44       broken clouds
# 5       10.36           clear sky
# 6        2.39     overcast clouds
# 7       16.02          light rain
# 8        8.05           clear sky
# 9        3.24       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")
